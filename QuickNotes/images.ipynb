# %% [markdown]
# For working with images, we are going to import Image from PIL

# %%
from PIL import Image

mapa = Image.open('mapa_lol.png')

# %%
type(mapa)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
mapa

#You may need to type mapa.show() in other IDEs other than jupiter
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=220x220 at 0x7F4659152F50>

# %%
mapa.size
# Out:
# (220, 220)

# %%
mapa.filename
# Out:
# 'mapa_lol.png'

# %%
mapa.format_description
# Out:
# 'Portable network graphics'

# %% [markdown]
# Cropping images is usefull for having a small size of the picture that we passed in

# %%
mapa.crop((0,0,100,100))

# it works like x ; y form top left to the bottom
# then we set h and w, to set the crop.
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F4648D88040>

# %%
mapa
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=220x220 at 0x7F4659152F50>

# %%
mapa.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F4659151F90>

# %% [markdown]
# We can make transparency, copy, paste, check the documentation for more if interested for any operation.
